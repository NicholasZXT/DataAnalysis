# %%
import openpyxl
import json
from collections import Counter
import pandas as pd
import re
from collections import Counter, defaultdict
import random
from copy import deepcopy
import pdb

# %%
def load_xlsx_data(filename, sheetname="Sheet1", header=True):
    """ Load xls data
    """
    workbook = openpyxl.load_workbook(filename)
    worksheet = workbook[sheetname]
    headers = []
    contents = []
    for idx, row in enumerate(worksheet.iter_rows()):
        row_values = [cell.value for cell in row]
        if idx == 0 and header:
            headers = row_values
            continue
        if header:
            row_values = dict(zip(headers, row_values))
        contents.append(row_values)
    return contents


RGX_INTENTS = re.compile('intents":(.*?])}]')


def find_dr(target, rgx=RGX_INTENTS):
    res = rgx.findall(target)
    if not res:
        return []
    targ_str = res[0]
    try:
        res = json.loads(targ_str)
    except:
        res = []
    return res
    

def convert_data(rec):
    rank_order = [x.split("|") for x in rec["rank_order"].split("\n") if x] if rec["rank_order"] else []
    dialog_root = find_dr(rec["dialog_root_responsebody"])
    try:
        nlu_model = json.loads(rec["nlu_model_nlp"])
    except:
        nlu_model = {}
    try:
        grammar_body = json.loads(rec["grammar_process_responsebody"])
    except:
        grammar_body = {}
    try:
        model_top1 = json.loads(rec["result"])
    except:
        model_top1 = []
    res = {
        "model_topn": nlu_model,
        "query": grammar_body.get("query", ""),
        "entities": grammar_body.get("entities", []),
        "grammar_topn": grammar_body.get("intents", []),
        "rank_order": [{"domain": x[0], "intent": x[1]} for x in rank_order if len(x) == 2],
        "use_nlu_model": rec["should_use_this"],
        "dialog_root": dialog_root,
        "traceid": rec["p_traceid"],
        "model_top1": model_top1
    }
    return res

# %%
# raw_data = load_xlsx_data("./data_0615.xlsx", sheetname="Sheet")
raw_data = load_xlsx_data("‪D:\Desktop\MINI-NLU-全量数据(6.15-6.21).xlsx", sheetname="Sheet")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-7f11e5d8b76e> in <module>
#       1 # raw_data = load_xlsx_data("./data_0615.xlsx", sheetname="Sheet")
# ----> 2 raw_data = load_xlsx_data("‪D:\Desktop\MINI-NLU-全量数据(6.15-6.21).xlsx", sheetname="Sheet")
#
# <ipython-input-2-ab706ae67823> in load_xlsx_data(filename, sheetname, header)
#       2     """ Load xls data
#       3     """
# ----> 4     workbook = openpyxl.load_workbook(filename)
#       5     worksheet = workbook[sheetname]
#       6     headers = []
#
# ~\Anaconda3\lib\site-packages\openpyxl\reader\excel.py in load_workbook(filename, read_only, keep_vba, data_only, keep_links)
#     311     """
#     312     reader = ExcelReader(filename, read_only, keep_vba,
# --> 313                         data_only, keep_links)
#     314     reader.read()
#     315     return reader.wb
#
# ~\Anaconda3\lib\site-packages\openpyxl\reader\excel.py in __init__(self, fn, read_only, keep_vba, data_only, keep_links)
#     122     def __init__(self,  fn, read_only=False, keep_vba=KEEP_VBA,
#     123                   data_only=False, keep_links=True):
# --> 124         self.archive = _validate_archive(fn)
#     125         self.valid_files = self.archive.namelist()
#     126         self.read_only = read_only
#
# ~\Anaconda3\lib\site-packages\openpyxl\reader\excel.py in _validate_archive(filename)
#      94             raise InvalidFileException(msg)
#      95
# ---> 96     archive = ZipFile(filename, 'r')
#      97     return archive
#      98
#
# ~\Anaconda3\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1238             while True:
#    1239                 try:
# -> 1240                     self.fp = io.open(file, filemode)
#    1241                 except OSError:
#    1242                     if filemode in modeDict:
#
# OSError: [Errno 22] Invalid argument: '\u202aD:\\Desktop\\MINI-NLU-全量数据(6.15-6.21).xlsx'

# %%
recs = [x for x in raw_data if "怎么说呢" in x["grammar_process_responsebody"]]

# %%
recs[0]["result"]
# Out:
# 'null'

# %%
raw_data[0].keys()
# Out:
# dict_keys(['dates', 'p_traceid', 'b_client_id', 'nlu_model_nlp', 'nlu_model_tags', 'grammar_process_lid', 'grammar_process_responsebody', 'grammar_process_tags', 'dialog_root_responsebody', 'dialog_root_tags', 'standard_log_lid', 'should_use_this', 'result', 'rank_order', 'standard_log_tags'])

# %%
raw_data[0]["result"]
# Out:
# '[{"intent_id":60298221125632,"intent_name":"next_song","grammar_pkg_id":60110064582656,"grammar_pkg_name":"music_2"},{"intent_id":60212523106304,"intent_name":"stop_music","grammar_pkg_id":60110064582656,"grammar_pkg_name":"music_2"},{"intent_id":60200175075328,"intent_name":"collect_music","grammar_pkg_id":60110064582656,"grammar_pkg_name":"music_2"},{"intent_id":60300637044736,"intent_name":"pause_music","grammar_pkg_id":60110064582656,"grammar_pkg_name":"music_2"},{"intent_id":60996413358080,"intent_name":"cancel_pause","grammar_pkg_id":60110064582656,"grammar_pkg_name":"music_2"},{"intent_id":75543887020032,"intent_name":"next_one","grammar_pkg_id":74049716486144,"grammar_pkg_name":"fm_2"},{"intent_id":76090908147712,"intent_name":"pause_book","grammar_pkg_id":74049716486144,"grammar_pkg_name":"fm_2"}]'

# %%
data = [convert_data(x) for x in raw_data]

# %%
data[0]
# Out:
# {'model_topn': [{'domain': 'music_2',
#    'domain_confidence': 0.2065281867980957,
#    'intent': 'cancel_pause',
#    'intent_confidence': 0.6017264127731323,
#    'slots': {},
#    'slots_confidence': 0.9999412298202515},
#   {'domain': 'fm_2',
#    'domain_confidence': 0.19012224674224854,
#    'intent': 'pause_book',
#    'intent_confidence': 0.9841967225074768,
#    'slots': {},
#    'slots_confidence': 0},
#   {'domain': 'music_2',
#    'domain_confidence': 0.19012224674224854,
#    'intent': 'next_song',
#    'intent_confidence': 0.807354211807251,
#    'slots': {},
#    'slots_confidence': 0},
#   {'domain': 'fm_2',
#    'domain_confidence': 0.19012224674224854,
#    'intent': 'next_one',
#    'intent_confidence': 0.807354211807251,
#    'slots': {},
#    'slots_confidence': 0},
#   {'domain': 'music_2',
#    'domain_confidence': 0.1305018663406372,
#    'intent': 'pause_music',
#    'intent_confidence': 0.9904394149780273,
#    'slots': {},
#    'slots_confidence': 0.9999434947967529},
#   {'domain': 'music_2',
#    'domain_confidence': 0.1305018663406372,
#    'intent': 'stop_music',
#    'intent_confidence': 0.9618251323699951,
#    'slots': {},
#    'slots_confidence': 0.9999434947967529},
#   {'domain': 'music_2',
#    'domain_confidence': 0.1305018663406372,
#    'intent': 'collect_music',
#    'intent_confidence': 0.6064225435256958,
#    'slots': {},
#    'slots_confidence': 0.9999434947967529}],
#  'query': '别播了',
#  'entities': [{'text': '别',
#    'value': 'IuWIqyI=',
#    'dict_name': 'SEMANTIC_TAG_ACTION_CANCEL',
#    'offset': 1,
#    'type': 'NORMAL',
#    'is_sys': 1},
#   {'text': '别播',
#    'value': 'IuWIq+aSrSI=',
#    'dict_name': 'SEMANTIC_TAG_ACTION_CANCEL',
#    'offset': 2,
#    'type': 'NORMAL',
#    'is_sys': 1},
#   {'text': '别播了',
#    'value': 'IuWIq+aSreS6hiI=',
#    'dict_name': 'SEMANTIC_TAG_COMMAND_STOP',
#    'offset': 3,
#    'type': 'NORMAL',
#    'is_sys': 1},
#   {'text': '了',
#    'value': 'IuS6hiI=',
#    'dict_name': 'invalid_word',
#    'start_pos': 2,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '播',
#    'value': 'IuaSrSI=',
#    'dict_name': 'SEMANTIC_TAG_MUSIC_WANT',
#    'start_pos': 1,
#    'offset': 1,
#    'type': 'NORMAL',
#    'is_sys': 1},
#   {'text': '播',
#    'value': 'IuaSrSI=',
#    'dict_name': 'play_verb',
#    'start_pos': 1,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '播',
#    'value': 'IuaSreaUviI=',
#    'dict_name': 'general_open_page',
#    'start_pos': 1,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '别',
#    'value': 'IuWIqyI=',
#    'dict_name': 'song_noun',
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '别播了',
#    'value': 'IuWIq+aSreS6hiI=',
#    'dict_name': 'pause_verb',
#    'offset': 3,
#    'type': 'NORMAL'},
#   {'text': '播',
#    'value': 'IuaSrSI=',
#    'dict_name': 'delete_pause',
#    'start_pos': 1,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '播',
#    'value': 'IuaSrSI=',
#    'dict_name': 'command_play',
#    'start_pos': 1,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '别',
#    'value': 'IuWIqyI=',
#    'dict_name': 'no_prefix',
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '播',
#    'value': 'IuaSrSI=',
#    'dict_name': 'fm_play_verb',
#    'start_pos': 1,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '了',
#    'value': 'IuS6hiI=',
#    'dict_name': 'fm_suffix',
#    'start_pos': 2,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '播',
#    'value': 'IuaSrSI=',
#    'dict_name': 'fm_play_verb_1',
#    'start_pos': 1,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '播',
#    'value': 'IuaSreaUviI=',
#    'dict_name': 'play_verb_books',
#    'start_pos': 1,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '别',
#    'value': 'IuWIqyI=',
#    'dict_name': 'fm_privative',
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '别播了',
#    'value': 'IuWIq+aUvuS6hiI=',
#    'dict_name': 'fm_pause',
#    'offset': 3,
#    'type': 'NORMAL'},
#   {'text': '播',
#    'value': 'IuaSrSI=',
#    'dict_name': 'video_watch_verb',
#    'start_pos': 1,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '了',
#    'value': 'IuS6hiI=',
#    'dict_name': 'weather_invalid_word',
#    'start_pos': 2,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '了',
#    'value': 'IuS6hiI=',
#    'dict_name': 'calendar_invalid',
#    'start_pos': 2,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '了',
#    'value': 'IuS6hiI=',
#    'dict_name': 'suffix_interrogative',
#    'start_pos': 2,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '播',
#    'value': 'IuaSrSI=',
#    'dict_name': 'please',
#    'start_pos': 1,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '了',
#    'value': 'IuS6hiI=',
#    'dict_name': 'alarm_invalid_word',
#    'start_pos': 2,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '了',
#    'value': 'IuS6hiI=',
#    'dict_name': 'camera_invalid',
#    'start_pos': 2,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '了',
#    'value': 'IuS6hiI=',
#    'dict_name': 'album_invalid',
#    'start_pos': 2,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '了',
#    'value': 'IuS6hiI=',
#    'dict_name': 'iot_suffix',
#    'start_pos': 2,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '了',
#    'value': 'IuS6hiI=',
#    'dict_name': 'chat_invaild',
#    'start_pos': 2,
#    'offset': 1,
#    'type': 'NORMAL'}],
#  'grammar_topn': [{'intent_id': 60300637044736,
#    'intent_name': 'pause_music',
#    'grammar_id': 61734040502272,
#    'grammar_pkg_id': 60110064582656,
#    'grammar_pkg_name': 'music_2'},
#   {'intent_id': 60170982719488,
#    'intent_name': 'search_music',
#    'grammar_id': 94485858877454,
#    'slots': [{'slot_name': 'song',
#      'slot_type': 'NORMAL',
#      'dict_name': 'song_noun',
#      'text': '别',
#      'value': 'IuWIqyI=',
#      'slot_id': 60262552895489}],
#    'grammar_pkg_id': 60109955530752,
#    'grammar_pkg_name': 'music_1'},
#   {'intent_id': 76090908147712,
#    'intent_name': 'pause_book',
#    'grammar_id': 124759153967105,
#    'grammar_pkg_id': 74049716486144,
#    'grammar_pkg_name': 'fm_2'},
#   {'intent_id': 76090908147712,
#    'intent_name': 'pause_book',
#    'grammar_id': 76091377975296,
#    'grammar_pkg_id': 74049716486144,
#    'grammar_pkg_name': 'fm_2'}],
#  'rank_order': [{'domain': 'music_3', 'intent': 'select_item'},
#   {'domain': 'general_command_3', 'intent': 'change_tab'},
#   {'domain': 'general_command_3', 'intent': 'go_top'},
#   {'domain': 'general_command_3', 'intent': 'go_bottom'},
#   {'domain': 'general_command_3', 'intent': 'select_item'},
#   {'domain': 'general_command_3', 'intent': 'select_page'},
#   {'domain': 'general_command_3', 'intent': 'cancel'},
#   {'domain': 'general_command_3', 'intent': 'slide_up'},
#   {'domain': 'general_command_3', 'intent': 'slide_down'},
#   {'domain': 'general_command_3', 'intent': 'next'},
#   {'domain': 'general_command_3', 'intent': 'last'},
#   {'domain': 'general_command_3', 'intent': 'next_page'},
#   {'domain': 'general_command_3', 'intent': 'last_page'},
#   {'domain': 'general_command_3', 'intent': 'delete'},
#   {'domain': 'general_command_3', 'intent': 'confirm'},
#   {'domain': 'general_command_3', 'intent': 'open_page'},
#   {'domain': 'general_command_3', 'intent': 'close_page'},
#   {'domain': 'music_2', 'intent': 'open_collection'},
#   {'domain': 'music_2', 'intent': 'open_list'},
#   {'domain': 'music_2', 'intent': 'next_song'},
#   {'domain': 'music_2', 'intent': 'open_lyrics'},
#   {'domain': 'music_2', 'intent': 'delete_collect'},
#   {'domain': 'music_2', 'intent': 'stop_music'},
#   {'domain': 'music_2', 'intent': 'collect_music'},
#   {'domain': 'music_2', 'intent': 'pause_music'},
#   {'domain': 'music_2', 'intent': 'order_play'},
#   {'domain': 'music_2', 'intent': 'previous_song'},
#   {'domain': 'music_2', 'intent': 'list_cycle'},
#   {'domain': 'music_2', 'intent': 'cancel_pause'},
#   {'domain': 'music_2', 'intent': 'open_playlist'},
#   {'domain': 'music_2', 'intent': 'random_play'},
#   {'domain': 'music_2', 'intent': 'change_music_without_slot'},
#   {'domain': 'music_2', 'intent': 'single_cycle_without_slot'},
#   {'domain': 'music_2', 'intent': 'close_playlist'},
#   {'domain': 'music_2', 'intent': 'change_music'},
#   {'domain': 'music_2', 'intent': 'single_cycle'},
#   {'domain': 'general_command_2', 'intent': 'play'},
#   {'domain': 'general_command_2', 'intent': 'play_from_start'},
#   {'domain': 'general_command_2', 'intent': 'pause'},
#   {'domain': 'music_1', 'intent': 'play_collection'},
#   {'domain': 'music_1', 'intent': 'search_music_without_slot'},
#   {'domain': 'music_1', 'intent': 'search_music'},
#   {'domain': 'global_command', 'intent': 'open_app'},
#   {'domain': 'global_command', 'intent': 'open_applet'},
#   {'domain': 'global_command', 'intent': 'volume_up'},
#   {'domain': 'global_command', 'intent': 'volume_down'},
#   {'domain': 'global_command', 'intent': 'brightness_down'},
#   {'domain': 'global_command', 'intent': 'set_volume'},
#   {'domain': 'global_command', 'intent': 'brightness_up'},
#   {'domain': 'global_command', 'intent': 'set_brightness'},
#   {'domain': 'global_command', 'intent': 'close_app'},
#   {'domain': 'global_command', 'intent': 'power_off'},
#   {'domain': 'global_command', 'intent': 'restart'},
#   {'domain': 'global_command', 'intent': 'lock_screen'},
#   {'domain': 'global_command', 'intent': 'mute'},
#   {'domain': 'global_command', 'intent': 'unmute'},
#   {'domain': 'global_command', 'intent': 'go_setting'},
#   {'domain': 'global_command', 'intent': 'return_home'},
#   {'domain': 'global_command', 'intent': 'close_camera'},
#   {'domain': 'global_command', 'intent': 'open_mic'},
#   {'domain': 'global_command', 'intent': 'close_mic'},
#   {'domain': 'global_command', 'intent': 'open_night_mode'},
#   {'domain': 'global_command', 'intent': 'close_night_mode'},
#   {'domain': 'global_command', 'intent': 'open_camera'},
#   {'domain': 'global_command', 'intent': 'return'},
#   {'domain': 'global_command', 'intent': 'close_applet'},
#   {'domain': 'global_command', 'intent': 'come'},
#   {'domain': 'global_command', 'intent': 'do_not_move'},
#   {'domain': 'global_command', 'intent': 'start_follow_me'},
#   {'domain': 'global_command', 'intent': 'go_back'},
#   {'domain': 'global_command', 'intent': 'close_screen'},
#   {'domain': 'global_command', 'intent': 'go_to_sleep'},
#   {'domain': 'fm_2', 'intent': 'history_play'},
#   {'domain': 'fm_2', 'intent': 'continue_play'},
#   {'domain': 'fm_2', 'intent': 'now_play_name'},
#   {'domain': 'fm_2', 'intent': 'last_one'},
#   {'domain': 'fm_2', 'intent': 'next_one'},
#   {'domain': 'fm_2', 'intent': 'chapter_list'},
#   {'domain': 'fm_2', 'intent': 'choose_chapter'},
#   {'domain': 'fm_2', 'intent': 'pause_book'},
#   {'domain': 'fm_2', 'intent': 'single_play'},
#   {'domain': 'fm_2', 'intent': 'list_play'},
#   {'domain': 'fm_2', 'intent': 'forward_way'},
#   {'domain': 'fm_2', 'intent': 'backward_way'},
#   {'domain': 'fm_2', 'intent': 'from_play'},
#   {'domain': 'fm_2', 'intent': 'forward_time'},
#   {'domain': 'fm_2', 'intent': 'back_page'},
#   {'domain': 'fm_2', 'intent': 'stop_opk'},
#   {'domain': 'fm_2', 'intent': 'change_radio'},
#   {'domain': 'fm_2', 'intent': 'change_fm'},
#   {'domain': 'fm_2', 'intent': 'backward_time'},
#   {'domain': 'fm_2', 'intent': 'random_play'},
#   {'domain': 'fm_2', 'intent': 'order_play'},
#   {'domain': 'fm_2', 'intent': 'change_withoutslot'},
#   {'domain': 'fm_1', 'intent': 'search_tab'},
#   {'domain': 'fm_1', 'intent': 'search_fm_withoutslot'},
#   {'domain': 'fm_1', 'intent': 'search_fm'},
#   {'domain': 'fm_1', 'intent': 'search_radio_withoutslot'},
#   {'domain': 'fm_1', 'intent': 'search_radio'},
#   {'domain': 'video_2', 'intent': 'start_search'},
#   {'domain': 'video_2', 'intent': 'buy_vip'},
#   {'domain': 'video_2', 'intent': 'login'},
#   {'domain': 'video_2', 'intent': 'start_record'},
#   {'domain': 'video_2', 'intent': 'logout'},
#   {'domain': 'video_2', 'intent': 'exit'},
#   {'domain': 'video_2', 'intent': 'back'},
#   {'domain': 'video_1', 'intent': 'start_aiqiyi'},
#   {'domain': 'video_1', 'intent': 'search_video_tab'},
#   {'domain': 'video_1', 'intent': 'search_video'},
#   {'domain': 'video_1', 'intent': 'play'},
#   {'domain': 'general', 'intent': 'answer_time'},
#   {'domain': 'weather', 'intent': 'get_temperature'},
#   {'domain': 'weather', 'intent': 'get_weather'},
#   {'domain': 'weather', 'intent': 'get_haze'},
#   {'domain': 'weather', 'intent': 'get_rain'},
#   {'domain': 'weather', 'intent': 'get_snow'},
#   {'domain': 'alarm', 'intent': 'set_alarm'},
#   {'domain': 'alarm', 'intent': 'view_alarm'},
#   {'domain': 'alarm', 'intent': 'stop_alarm'},
#   {'domain': 'alarm', 'intent': 'delete_alarm'},
#   {'domain': 'videocall_1', 'intent': 'Initiate_videocall'},
#   {'domain': 'navigation_1', 'intent': 'start_navigation'},
#   {'domain': 'camera_1', 'intent': 'open_camera'},
#   {'domain': 'album_1', 'intent': 'open_album'},
#   {'domain': 'smart_home_1', 'intent': 'close'},
#   {'domain': 'smart_home_1', 'intent': 'set_model'},
#   {'domain': 'smart_home_1', 'intent': 'cold_color'},
#   {'domain': 'smart_home_1', 'intent': 'down_gear'},
#   {'domain': 'smart_home_1', 'intent': 'down_light'},
#   {'domain': 'smart_home_1', 'intent': 'down_temperature'},
#   {'domain': 'smart_home_1', 'intent': 'get_device_state'},
#   {'domain': 'smart_home_1', 'intent': 'set_gear'},
#   {'domain': 'smart_home_1', 'intent': 'set_light'},
#   {'domain': 'smart_home_1', 'intent': 'open'},
#   {'domain': 'smart_home_1', 'intent': 'set_temperature'},
#   {'domain': 'smart_home_1', 'intent': 'up_light'},
#   {'domain': 'smart_home_1', 'intent': 'up_gear'},
#   {'domain': 'smart_home_1', 'intent': 'warm_color'},
#   {'domain': 'smart_home_1', 'intent': 'up_temperature'},
#   {'domain': 'chat_1', 'intent': 'start_chat'},
#   {'domain': 'chat_1', 'intent': 'end_chat'}],
#  'use_nlu_model': '0',
#  'dialog_root': [{'intent_id': 60300637044736,
#    'intent_name': 'pause_music',
#    'grammar_id': 61734040502272,
#    'grammar_pkg_id': 60110064582656,
#    'domain_name': 'music_2'},
#   {'intent_id': 60170982719488,
#    'intent_name': 'search_music',
#    'slots': [{'slot_name': 'song',
#      'text': '别',
#      'dict_name': 'song_noun',
#      'value': 'IuWIqyI=',
#      'slot_type': 'NORMAL',
#      'slot_id': 60262552895489}],
#    'grammar_id': 94485858877454,
#    'grammar_pkg_id': 60109955530752,
#    'domain_name': 'music_1'},
#   {'intent_id': 76090908147712,
#    'intent_name': 'pause_book',
#    'grammar_id': 124759153967105,
#    'grammar_pkg_id': 74049716486144,
#    'domain_name': 'fm_2'},
#   {'intent_id': 76090908147712,
#    'intent_name': 'pause_book',
#    'grammar_id': 76091377975296,
#    'grammar_pkg_id': 74049716486144,
#    'domain_name': 'fm_2'}],
#  'traceid': '0cad054cd742d03b',
#  'model_top1': [{'intent_id': 60298221125632,
#    'intent_name': 'next_song',
#    'grammar_pkg_id': 60110064582656,
#    'grammar_pkg_name': 'music_2'},
#   {'intent_id': 60212523106304,
#    'intent_name': 'stop_music',
#    'grammar_pkg_id': 60110064582656,
#    'grammar_pkg_name': 'music_2'},
#   {'intent_id': 60200175075328,
#    'intent_name': 'collect_music',
#    'grammar_pkg_id': 60110064582656,
#    'grammar_pkg_name': 'music_2'},
#   {'intent_id': 60300637044736,
#    'intent_name': 'pause_music',
#    'grammar_pkg_id': 60110064582656,
#    'grammar_pkg_name': 'music_2'},
#   {'intent_id': 60996413358080,
#    'intent_name': 'cancel_pause',
#    'grammar_pkg_id': 60110064582656,
#    'grammar_pkg_name': 'music_2'},
#   {'intent_id': 75543887020032,
#    'intent_name': 'next_one',
#    'grammar_pkg_id': 74049716486144,
#    'grammar_pkg_name': 'fm_2'},
#   {'intent_id': 76090908147712,
#    'intent_name': 'pause_book',
#    'grammar_pkg_id': 74049716486144,
#    'grammar_pkg_name': 'fm_2'}]}

# %%
def clean_str(target):
    if not target:
        return ""
    res = target.strip().lower()
    res = re.sub(r'^[^\w\s]', '', res)
    res = re.sub(r'[^\w\s]$', '', res)
    return res

print(clean_str(" 今天天气好不好？ "))


AWAKENS = ["小豹", "小雅"]

def all_awakens(target, awakens=AWAKENS):
    if len(target) % 2 != 0:
        return False
    parts = [target[i: i + 2] for i in range(0, len(target), 2)]
    parts = set(parts)
    return all(x in awakens for x in parts)



def get_top1_domain(rec):
    result = "other"
    for intent in rec.get("dialog_root", []):
        domain = intent["domain_name"]
        if domain.startswith("music_"):
            result = "music"
            break
        if domain.startswith("fm_"):
            result = "fm"
            break
        if domain != "other":
            result = "XXX"
    if result != "other":
        return result
    for intent in rec.get("model_topn", []):
        domain = intent["domain"]
        if domain.startswith("music_"):
            result = "music"
            break
        if domain.startswith("fm_"):
            result = "fm"
            break
        if domain != "other":
            result = "XXX"
    return result


def sample_records(data):
    valid_count = 0
    t2idx = defaultdict(list)
    qcounts = Counter()
    for idx, rec in enumerate(data):
        query = rec.get("query", "")
        norm_query = clean_str(query)
        rec["norm_query"] = norm_query
        if not norm_query:
            t2idx["empty"].append(idx)
            continue
        if all_awakens(norm_query):
            t2idx["awakens"].append(idx)
            continue
        qcounts[norm_query] += 1
        valid_count += 1
        domain = get_top1_domain(rec)
        t2idx[domain].append(idx)
    samples = []
    aggregates = 0
    currents = set()
    for domain, indexes in t2idx.items():
        if domain in ("empty", "awakens"):
            continue
        idxlen = len(indexes)
        aggregates += idxlen
        if aggregates >= valid_count:
            num = 2000 - len(samples)
        else:
            num = int(idxlen / valid_count * 2000)
        if not num:
            continue
        qset = set([data[x]["query"] for x in indexes])
        if len(qset) < num:
            pdb.set_trace()
        count = 0
        while count < num:
            idx = random.choice(indexes)
            rec = data[idx]
            query = rec["norm_query"]
            indexes.remove(idx)
            if query in currents:
                continue
            currents.add(query)
            rec = deepcopy(data[idx])
            rec = deepcopy(data[idx])
            rec["dtype"] = domain
            rec["dcount"] = idxlen
            rec["qcount"] = qcounts[query]
            samples.append(rec)
            count += 1
    return samples, t2idx, qcounts
# Out:
# 今天天气好不好

# %%
samples, t2idx, qcounts = sample_records(data)

# %%
def get_domains(target):
    for intent in target:
        domain = intent.get("grammar_pkg_name", intent.get("domain_name", intent.get("domain")))
        if domain.startswith("music_"):
            yield "music"
            continue
        if domain.startswith("fm_"):
            yield "fm"
            continue
        if domain != "other":
            yield "XXX"
        else:
            yield "other"

def describe_data(data, target="dialog_root"):
    qcounts = Counter()
    for rec in data:
        qcounts["total"] += 1
        query = rec.get("query", "")
        norm_query = clean_str(query)
        rec["norm_query"] = norm_query
        if not norm_query:
            qcounts["empty"] += 1
            continue
        if all_awakens(norm_query):
            qcounts["awakens"] += 1
            continue
        qcounts["valid"] += 1
        domains = list(set(x for x in get_domains(rec.get(target, []))))
        if not domains:
            domains = ["other"]
        qcounts.update(domains)
    print(target, qcounts)
    return qcounts


_ = describe_data(data)
_ = describe_data(data, target="model_topn")
# Out:
# dialog_root Counter({'total': 9190, 'valid': 8673, 'XXX': 3988, 'other': 3322, 'fm': 1241, 'music': 1099, 'awakens': 378, 'empty': 139})
# model_topn Counter({'total': 9190, 'valid': 8673, 'other': 4802, 'fm': 4010, 'music': 3999, 'XXX': 959, 'awakens': 378, 'empty': 139})

# %%
data[0]
# Out:
# {'model_topn': [{'domain': 'music_2',
#    'domain_confidence': 0.2065281867980957,
#    'intent': 'cancel_pause',
#    'intent_confidence': 0.6017264127731323,
#    'slots': {},
#    'slots_confidence': 0.9999412298202515},
#   {'domain': 'fm_2',
#    'domain_confidence': 0.19012224674224854,
#    'intent': 'pause_book',
#    'intent_confidence': 0.9841967225074768,
#    'slots': {},
#    'slots_confidence': 0},
#   {'domain': 'music_2',
#    'domain_confidence': 0.19012224674224854,
#    'intent': 'next_song',
#    'intent_confidence': 0.807354211807251,
#    'slots': {},
#    'slots_confidence': 0},
#   {'domain': 'fm_2',
#    'domain_confidence': 0.19012224674224854,
#    'intent': 'next_one',
#    'intent_confidence': 0.807354211807251,
#    'slots': {},
#    'slots_confidence': 0},
#   {'domain': 'music_2',
#    'domain_confidence': 0.1305018663406372,
#    'intent': 'pause_music',
#    'intent_confidence': 0.9904394149780273,
#    'slots': {},
#    'slots_confidence': 0.9999434947967529},
#   {'domain': 'music_2',
#    'domain_confidence': 0.1305018663406372,
#    'intent': 'stop_music',
#    'intent_confidence': 0.9618251323699951,
#    'slots': {},
#    'slots_confidence': 0.9999434947967529},
#   {'domain': 'music_2',
#    'domain_confidence': 0.1305018663406372,
#    'intent': 'collect_music',
#    'intent_confidence': 0.6064225435256958,
#    'slots': {},
#    'slots_confidence': 0.9999434947967529}],
#  'query': '别播了',
#  'entities': [{'text': '别',
#    'value': 'IuWIqyI=',
#    'dict_name': 'SEMANTIC_TAG_ACTION_CANCEL',
#    'offset': 1,
#    'type': 'NORMAL',
#    'is_sys': 1},
#   {'text': '别播',
#    'value': 'IuWIq+aSrSI=',
#    'dict_name': 'SEMANTIC_TAG_ACTION_CANCEL',
#    'offset': 2,
#    'type': 'NORMAL',
#    'is_sys': 1},
#   {'text': '别播了',
#    'value': 'IuWIq+aSreS6hiI=',
#    'dict_name': 'SEMANTIC_TAG_COMMAND_STOP',
#    'offset': 3,
#    'type': 'NORMAL',
#    'is_sys': 1},
#   {'text': '了',
#    'value': 'IuS6hiI=',
#    'dict_name': 'invalid_word',
#    'start_pos': 2,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '播',
#    'value': 'IuaSrSI=',
#    'dict_name': 'SEMANTIC_TAG_MUSIC_WANT',
#    'start_pos': 1,
#    'offset': 1,
#    'type': 'NORMAL',
#    'is_sys': 1},
#   {'text': '播',
#    'value': 'IuaSrSI=',
#    'dict_name': 'play_verb',
#    'start_pos': 1,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '播',
#    'value': 'IuaSreaUviI=',
#    'dict_name': 'general_open_page',
#    'start_pos': 1,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '别',
#    'value': 'IuWIqyI=',
#    'dict_name': 'song_noun',
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '别播了',
#    'value': 'IuWIq+aSreS6hiI=',
#    'dict_name': 'pause_verb',
#    'offset': 3,
#    'type': 'NORMAL'},
#   {'text': '播',
#    'value': 'IuaSrSI=',
#    'dict_name': 'delete_pause',
#    'start_pos': 1,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '播',
#    'value': 'IuaSrSI=',
#    'dict_name': 'command_play',
#    'start_pos': 1,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '别',
#    'value': 'IuWIqyI=',
#    'dict_name': 'no_prefix',
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '播',
#    'value': 'IuaSrSI=',
#    'dict_name': 'fm_play_verb',
#    'start_pos': 1,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '了',
#    'value': 'IuS6hiI=',
#    'dict_name': 'fm_suffix',
#    'start_pos': 2,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '播',
#    'value': 'IuaSrSI=',
#    'dict_name': 'fm_play_verb_1',
#    'start_pos': 1,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '播',
#    'value': 'IuaSreaUviI=',
#    'dict_name': 'play_verb_books',
#    'start_pos': 1,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '别',
#    'value': 'IuWIqyI=',
#    'dict_name': 'fm_privative',
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '别播了',
#    'value': 'IuWIq+aUvuS6hiI=',
#    'dict_name': 'fm_pause',
#    'offset': 3,
#    'type': 'NORMAL'},
#   {'text': '播',
#    'value': 'IuaSrSI=',
#    'dict_name': 'video_watch_verb',
#    'start_pos': 1,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '了',
#    'value': 'IuS6hiI=',
#    'dict_name': 'weather_invalid_word',
#    'start_pos': 2,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '了',
#    'value': 'IuS6hiI=',
#    'dict_name': 'calendar_invalid',
#    'start_pos': 2,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '了',
#    'value': 'IuS6hiI=',
#    'dict_name': 'suffix_interrogative',
#    'start_pos': 2,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '播',
#    'value': 'IuaSrSI=',
#    'dict_name': 'please',
#    'start_pos': 1,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '了',
#    'value': 'IuS6hiI=',
#    'dict_name': 'alarm_invalid_word',
#    'start_pos': 2,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '了',
#    'value': 'IuS6hiI=',
#    'dict_name': 'camera_invalid',
#    'start_pos': 2,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '了',
#    'value': 'IuS6hiI=',
#    'dict_name': 'album_invalid',
#    'start_pos': 2,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '了',
#    'value': 'IuS6hiI=',
#    'dict_name': 'iot_suffix',
#    'start_pos': 2,
#    'offset': 1,
#    'type': 'NORMAL'},
#   {'text': '了',
#    'value': 'IuS6hiI=',
#    'dict_name': 'chat_invaild',
#    'start_pos': 2,
#    'offset': 1,
#    'type': 'NORMAL'}],
#  'grammar_topn': [{'intent_id': 60300637044736,
#    'intent_name': 'pause_music',
#    'grammar_id': 61734040502272,
#    'grammar_pkg_id': 60110064582656,
#    'grammar_pkg_name': 'music_2'},
#   {'intent_id': 60170982719488,
#    'intent_name': 'search_music',
#    'grammar_id': 94485858877454,
#    'slots': [{'slot_name': 'song',
#      'slot_type': 'NORMAL',
#      'dict_name': 'song_noun',
#      'text': '别',
#      'value': 'IuWIqyI=',
#      'slot_id': 60262552895489}],
#    'grammar_pkg_id': 60109955530752,
#    'grammar_pkg_name': 'music_1'},
#   {'intent_id': 76090908147712,
#    'intent_name': 'pause_book',
#    'grammar_id': 124759153967105,
#    'grammar_pkg_id': 74049716486144,
#    'grammar_pkg_name': 'fm_2'},
#   {'intent_id': 76090908147712,
#    'intent_name': 'pause_book',
#    'grammar_id': 76091377975296,
#    'grammar_pkg_id': 74049716486144,
#    'grammar_pkg_name': 'fm_2'}],
#  'rank_order': [{'domain': 'music_3', 'intent': 'select_item'},
#   {'domain': 'general_command_3', 'intent': 'change_tab'},
#   {'domain': 'general_command_3', 'intent': 'go_top'},
#   {'domain': 'general_command_3', 'intent': 'go_bottom'},
#   {'domain': 'general_command_3', 'intent': 'select_item'},
#   {'domain': 'general_command_3', 'intent': 'select_page'},
#   {'domain': 'general_command_3', 'intent': 'cancel'},
#   {'domain': 'general_command_3', 'intent': 'slide_up'},
#   {'domain': 'general_command_3', 'intent': 'slide_down'},
#   {'domain': 'general_command_3', 'intent': 'next'},
#   {'domain': 'general_command_3', 'intent': 'last'},
#   {'domain': 'general_command_3', 'intent': 'next_page'},
#   {'domain': 'general_command_3', 'intent': 'last_page'},
#   {'domain': 'general_command_3', 'intent': 'delete'},
#   {'domain': 'general_command_3', 'intent': 'confirm'},
#   {'domain': 'general_command_3', 'intent': 'open_page'},
#   {'domain': 'general_command_3', 'intent': 'close_page'},
#   {'domain': 'music_2', 'intent': 'open_collection'},
#   {'domain': 'music_2', 'intent': 'open_list'},
#   {'domain': 'music_2', 'intent': 'next_song'},
#   {'domain': 'music_2', 'intent': 'open_lyrics'},
#   {'domain': 'music_2', 'intent': 'delete_collect'},
#   {'domain': 'music_2', 'intent': 'stop_music'},
#   {'domain': 'music_2', 'intent': 'collect_music'},
#   {'domain': 'music_2', 'intent': 'pause_music'},
#   {'domain': 'music_2', 'intent': 'order_play'},
#   {'domain': 'music_2', 'intent': 'previous_song'},
#   {'domain': 'music_2', 'intent': 'list_cycle'},
#   {'domain': 'music_2', 'intent': 'cancel_pause'},
#   {'domain': 'music_2', 'intent': 'open_playlist'},
#   {'domain': 'music_2', 'intent': 'random_play'},
#   {'domain': 'music_2', 'intent': 'change_music_without_slot'},
#   {'domain': 'music_2', 'intent': 'single_cycle_without_slot'},
#   {'domain': 'music_2', 'intent': 'close_playlist'},
#   {'domain': 'music_2', 'intent': 'change_music'},
#   {'domain': 'music_2', 'intent': 'single_cycle'},
#   {'domain': 'general_command_2', 'intent': 'play'},
#   {'domain': 'general_command_2', 'intent': 'play_from_start'},
#   {'domain': 'general_command_2', 'intent': 'pause'},
#   {'domain': 'music_1', 'intent': 'play_collection'},
#   {'domain': 'music_1', 'intent': 'search_music_without_slot'},
#   {'domain': 'music_1', 'intent': 'search_music'},
#   {'domain': 'global_command', 'intent': 'open_app'},
#   {'domain': 'global_command', 'intent': 'open_applet'},
#   {'domain': 'global_command', 'intent': 'volume_up'},
#   {'domain': 'global_command', 'intent': 'volume_down'},
#   {'domain': 'global_command', 'intent': 'brightness_down'},
#   {'domain': 'global_command', 'intent': 'set_volume'},
#   {'domain': 'global_command', 'intent': 'brightness_up'},
#   {'domain': 'global_command', 'intent': 'set_brightness'},
#   {'domain': 'global_command', 'intent': 'close_app'},
#   {'domain': 'global_command', 'intent': 'power_off'},
#   {'domain': 'global_command', 'intent': 'restart'},
#   {'domain': 'global_command', 'intent': 'lock_screen'},
#   {'domain': 'global_command', 'intent': 'mute'},
#   {'domain': 'global_command', 'intent': 'unmute'},
#   {'domain': 'global_command', 'intent': 'go_setting'},
#   {'domain': 'global_command', 'intent': 'return_home'},
#   {'domain': 'global_command', 'intent': 'close_camera'},
#   {'domain': 'global_command', 'intent': 'open_mic'},
#   {'domain': 'global_command', 'intent': 'close_mic'},
#   {'domain': 'global_command', 'intent': 'open_night_mode'},
#   {'domain': 'global_command', 'intent': 'close_night_mode'},
#   {'domain': 'global_command', 'intent': 'open_camera'},
#   {'domain': 'global_command', 'intent': 'return'},
#   {'domain': 'global_command', 'intent': 'close_applet'},
#   {'domain': 'global_command', 'intent': 'come'},
#   {'domain': 'global_command', 'intent': 'do_not_move'},
#   {'domain': 'global_command', 'intent': 'start_follow_me'},
#   {'domain': 'global_command', 'intent': 'go_back'},
#   {'domain': 'global_command', 'intent': 'close_screen'},
#   {'domain': 'global_command', 'intent': 'go_to_sleep'},
#   {'domain': 'fm_2', 'intent': 'history_play'},
#   {'domain': 'fm_2', 'intent': 'continue_play'},
#   {'domain': 'fm_2', 'intent': 'now_play_name'},
#   {'domain': 'fm_2', 'intent': 'last_one'},
#   {'domain': 'fm_2', 'intent': 'next_one'},
#   {'domain': 'fm_2', 'intent': 'chapter_list'},
#   {'domain': 'fm_2', 'intent': 'choose_chapter'},
#   {'domain': 'fm_2', 'intent': 'pause_book'},
#   {'domain': 'fm_2', 'intent': 'single_play'},
#   {'domain': 'fm_2', 'intent': 'list_play'},
#   {'domain': 'fm_2', 'intent': 'forward_way'},
#   {'domain': 'fm_2', 'intent': 'backward_way'},
#   {'domain': 'fm_2', 'intent': 'from_play'},
#   {'domain': 'fm_2', 'intent': 'forward_time'},
#   {'domain': 'fm_2', 'intent': 'back_page'},
#   {'domain': 'fm_2', 'intent': 'stop_opk'},
#   {'domain': 'fm_2', 'intent': 'change_radio'},
#   {'domain': 'fm_2', 'intent': 'change_fm'},
#   {'domain': 'fm_2', 'intent': 'backward_time'},
#   {'domain': 'fm_2', 'intent': 'random_play'},
#   {'domain': 'fm_2', 'intent': 'order_play'},
#   {'domain': 'fm_2', 'intent': 'change_withoutslot'},
#   {'domain': 'fm_1', 'intent': 'search_tab'},
#   {'domain': 'fm_1', 'intent': 'search_fm_withoutslot'},
#   {'domain': 'fm_1', 'intent': 'search_fm'},
#   {'domain': 'fm_1', 'intent': 'search_radio_withoutslot'},
#   {'domain': 'fm_1', 'intent': 'search_radio'},
#   {'domain': 'video_2', 'intent': 'start_search'},
#   {'domain': 'video_2', 'intent': 'buy_vip'},
#   {'domain': 'video_2', 'intent': 'login'},
#   {'domain': 'video_2', 'intent': 'start_record'},
#   {'domain': 'video_2', 'intent': 'logout'},
#   {'domain': 'video_2', 'intent': 'exit'},
#   {'domain': 'video_2', 'intent': 'back'},
#   {'domain': 'video_1', 'intent': 'start_aiqiyi'},
#   {'domain': 'video_1', 'intent': 'search_video_tab'},
#   {'domain': 'video_1', 'intent': 'search_video'},
#   {'domain': 'video_1', 'intent': 'play'},
#   {'domain': 'general', 'intent': 'answer_time'},
#   {'domain': 'weather', 'intent': 'get_temperature'},
#   {'domain': 'weather', 'intent': 'get_weather'},
#   {'domain': 'weather', 'intent': 'get_haze'},
#   {'domain': 'weather', 'intent': 'get_rain'},
#   {'domain': 'weather', 'intent': 'get_snow'},
#   {'domain': 'alarm', 'intent': 'set_alarm'},
#   {'domain': 'alarm', 'intent': 'view_alarm'},
#   {'domain': 'alarm', 'intent': 'stop_alarm'},
#   {'domain': 'alarm', 'intent': 'delete_alarm'},
#   {'domain': 'videocall_1', 'intent': 'Initiate_videocall'},
#   {'domain': 'navigation_1', 'intent': 'start_navigation'},
#   {'domain': 'camera_1', 'intent': 'open_camera'},
#   {'domain': 'album_1', 'intent': 'open_album'},
#   {'domain': 'smart_home_1', 'intent': 'close'},
#   {'domain': 'smart_home_1', 'intent': 'set_model'},
#   {'domain': 'smart_home_1', 'intent': 'cold_color'},
#   {'domain': 'smart_home_1', 'intent': 'down_gear'},
#   {'domain': 'smart_home_1', 'intent': 'down_light'},
#   {'domain': 'smart_home_1', 'intent': 'down_temperature'},
#   {'domain': 'smart_home_1', 'intent': 'get_device_state'},
#   {'domain': 'smart_home_1', 'intent': 'set_gear'},
#   {'domain': 'smart_home_1', 'intent': 'set_light'},
#   {'domain': 'smart_home_1', 'intent': 'open'},
#   {'domain': 'smart_home_1', 'intent': 'set_temperature'},
#   {'domain': 'smart_home_1', 'intent': 'up_light'},
#   {'domain': 'smart_home_1', 'intent': 'up_gear'},
#   {'domain': 'smart_home_1', 'intent': 'warm_color'},
#   {'domain': 'smart_home_1', 'intent': 'up_temperature'},
#   {'domain': 'chat_1', 'intent': 'start_chat'},
#   {'domain': 'chat_1', 'intent': 'end_chat'}],
#  'use_nlu_model': '0',
#  'dialog_root': [{'intent_id': 60300637044736,
#    'intent_name': 'pause_music',
#    'grammar_id': 61734040502272,
#    'grammar_pkg_id': 60110064582656,
#    'domain_name': 'music_2'},
#   {'intent_id': 60170982719488,
#    'intent_name': 'search_music',
#    'slots': [{'slot_name': 'song',
#      'text': '别',
#      'dict_name': 'song_noun',
#      'value': 'IuWIqyI=',
#      'slot_type': 'NORMAL',
#      'slot_id': 60262552895489}],
#    'grammar_id': 94485858877454,
#    'grammar_pkg_id': 60109955530752,
#    'domain_name': 'music_1'},
#   {'intent_id': 76090908147712,
#    'intent_name': 'pause_book',
#    'grammar_id': 124759153967105,
#    'grammar_pkg_id': 74049716486144,
#    'domain_name': 'fm_2'},
#   {'intent_id': 76090908147712,
#    'intent_name': 'pause_book',
#    'grammar_id': 76091377975296,
#    'grammar_pkg_id': 74049716486144,
#    'domain_name': 'fm_2'}],
#  'traceid': '0cad054cd742d03b',
#  'model_top1': [{'intent_id': 60298221125632,
#    'intent_name': 'next_song',
#    'grammar_pkg_id': 60110064582656,
#    'grammar_pkg_name': 'music_2'},
#   {'intent_id': 60212523106304,
#    'intent_name': 'stop_music',
#    'grammar_pkg_id': 60110064582656,
#    'grammar_pkg_name': 'music_2'},
#   {'intent_id': 60200175075328,
#    'intent_name': 'collect_music',
#    'grammar_pkg_id': 60110064582656,
#    'grammar_pkg_name': 'music_2'},
#   {'intent_id': 60300637044736,
#    'intent_name': 'pause_music',
#    'grammar_pkg_id': 60110064582656,
#    'grammar_pkg_name': 'music_2'},
#   {'intent_id': 60996413358080,
#    'intent_name': 'cancel_pause',
#    'grammar_pkg_id': 60110064582656,
#    'grammar_pkg_name': 'music_2'},
#   {'intent_id': 75543887020032,
#    'intent_name': 'next_one',
#    'grammar_pkg_id': 74049716486144,
#    'grammar_pkg_name': 'fm_2'},
#   {'intent_id': 76090908147712,
#    'intent_name': 'pause_book',
#    'grammar_pkg_id': 74049716486144,
#    'grammar_pkg_name': 'fm_2'}]}

# %%
len(set(x["query"] for x in samples))
# Out:
# 2000

# %%
def save_jsonl(data, filename, descs):
    with open(filename, "w") as fout:
        for desc in descs:
            line = json.dumps(desc, ensure_ascii=False)
            fout.write("#" + line + "\n")
        for rec in data:
            line = json.dumps(rec, ensure_ascii=False)
            fout.write(line)
            fout.write("\n")

# %%
save_jsonl(
    filename="2020-06-16.jsonl",
    data=samples,
    descs=[
        {k: len(v) for k, v in t2idx.items()},
        #qcounts
    ])

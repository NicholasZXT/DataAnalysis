# %%
getwd()
# Out:
# [1] "/Users/danielzhang/Documents/Python-Projects/DataAnalysis/Practice"

# %%
library(ggplot2)

# %%
installed.packages()
# Out:
#                  Package
# BH               BH
# BalancedSampling BalancedSampling
# DBI              DBI
# EnvStats         EnvStats
# FNN              FNN
# Formula          Formula
# GISTools         GISTools
# Hmisc            Hmisc
# IRdisplay        IRdisplay
# IRkernel         IRkernel
# ISLR             ISLR
# KernSmooth       KernSmooth
# LearnBayes       LearnBayes
# MASS             MASS
# Matrix           Matrix
# MatrixModels     MatrixModels
# R.methodsS3      R.methodsS3
# R.oo             R.oo
# R.utils          R.utils
# R6               R6
# RANN             RANN
# RColorBrewer     RColorBrewer
# RCurl            RCurl
# Rcpp             Rcpp
# RcppEigen        RcppEigen
# RgoogleMaps      RgoogleMaps
# SDMTools         SDMTools
# SparseM          SparseM
# SpatialPack      SpatialPack
# TH.data          TH.data
# ⋮                ⋮
# stats4           stats4
# streamR          streamR
# stringi          stringi
# stringr          stringr
# survival         survival
# ...
